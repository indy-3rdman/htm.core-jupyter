# %%
# %run rdse.py --sparsity 0.02 --size 80 --minimum 0 --maximum 9 --resolution 0.1
# Out:
# Statistics:
# Encoded 180 inputs.
# Output SDR( 80 )
#     Sparsity Min/Mean/Std/Max 0.025 / 0.0250001 / 1.81511e-06 / 0.025
#     Activation Frequency Min/Mean/Std/Max 0 / 0.025 / 0.0222569 / 0.0888889
#     Entropy 0.897363
#     Overlap Min/Mean/Std/Max 0.5 / 0.756983 / 0.249902 / 1
