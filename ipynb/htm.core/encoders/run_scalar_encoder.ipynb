# %%
# %run scalar_encoder.py --activeBits 8 --size 80 --minimum 0 --maximum 9
# Out:
# Statistics:
# Encoded 144 inputs.
# Output SDR( 80 )
#     Sparsity Min/Mean/Std/Max 0.1 / 0.0999997 / 2.03093e-06 / 0.1
#     Activation Frequency Min/Mean/Std/Max 0.00694444 / 0.1 / 0.0263889 / 0.111111
#     Entropy 0.98371
#     Overlap Min/Mean/Std/Max 0.875 / 0.937063 / 0.0624985 / 1
