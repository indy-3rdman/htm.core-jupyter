# %%
# %run simhash_document_encoder.py --sparsity 0.02 --size 200
# Out:
# Statistics:
# 	Encoded 1000 Document inputs.
# 	Output: SDR( 200 )
#     Sparsity Min/Mean/Std/Max 0.02 / 0.0200001 / 6.26724e-07 / 0.02
#     Activation Frequency Min/Mean/Std/Max 0 / 0.02 / 0.0215172 / 0.125
#     Entropy 0.906531
#     Overlap Min/Mean/Std/Max 0 / 0.0382883 / 0.0927717 / 0.5
# Similarity:
# 	Reference:
# 		['animal', 'differ', 'low', 'made', 'spell', 'such', 'tell', 'us', 'well']
# 	MOST Similar (Distance = 2):
# 		['does', 'find', 'land', 'little', 'name', 'picture', 'three', 'well', 'work']
# 	LEAST Similar (Distance = 8):
# 		['here', 'house', 'little', 'must', 'near', 'off', 'place', 'think', 'us']
